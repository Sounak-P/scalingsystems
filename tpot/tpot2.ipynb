# %%
# Import required libraries
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np
# Out:
# /home/sounak/anaconda3/envs/mlops/lib/python3.11/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
# Load the data
titanic = pd.read_csv('titanic/train.csv')
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
titanic.groupby(['Pclass','Sex']).Survived.value_counts()
# Out:
# Pclass  Sex     Survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: count, dtype: int64

# %%
titanic.rename(columns={'Survived': 'class'}, inplace=True)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# class            int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
for cat in ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']:
    print("Number of levels in category '{0}': \b {1:2.2f} ".format(cat, titanic[cat].unique().size))
# Out:
# Number of levels in category 'Name': 891.00
# Number of levels in category 'Sex': 2.00
# Number of levels in category 'Ticket': 681.00
# Number of levels in category 'Cabin': 148.00
# Number of levels in category 'Embarked': 4.00

# %%
for cat in ['Sex', 'Embarked']:
    print("Levels for catgeory '{0}': {1}".format(cat, titanic[cat].unique()))
# Out:
# Levels for catgeory 'Sex': ['male' 'female']
# Levels for catgeory 'Embarked': ['S' 'C' 'Q' nan]

# %%
titanic['Sex'] = titanic['Sex'].map({'male':0,'female':1})
titanic['Embarked'] = titanic['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
titanic = titanic.fillna(-999)
pd.isnull(titanic).any()
# Out:
# PassengerId    False
# class          False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
CabinTrans = mlb.fit_transform([{str(val)} for val in titanic['Cabin'].values])

# %%
titanic_new = titanic.drop(['Name','Ticket','Cabin','class'], axis=1)

# %%
assert (len(titanic['Cabin'].unique()) == len(mlb.classes_)), "Not Equal" #check correct encoding done

# %%
titanic_new = np.hstack((titanic_new.values,CabinTrans))

# %%
np.isnan(titanic_new).any()
# Out:
# np.False_

# %%
titanic_class = titanic['class'].values

# %%
training_indices, validation_indices = training_indices, testing_indices = train_test_split(titanic.index, stratify = titanic_class, train_size=0.75, test_size=0.25)
training_indices.size, validation_indices.size
# Out:
# (668, 223)

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=10, max_eval_time_mins=0.04, population_size=40)
tpot.fit(titanic_new[training_indices], titanic_class[training_indices])
# Out:
#
# Generation 1 - Current best internal CV score: 0.8218157333632587
#
# Generation 2 - Current best internal CV score: 0.8218157333632587
#
# Generation 3 - Current best internal CV score: 0.8248232521602514
#
# Generation 4 - Current best internal CV score: 0.8248232521602514
#
# Generation 5 - Current best internal CV score: 0.8248232521602514
#
# Generation 6 - Current best internal CV score: 0.8263157894736842
#
# Generation 7 - Current best internal CV score: 0.8263157894736842
#
# Generation 8 - Current best internal CV score: 0.8263157894736842
#
# Generation 9 - Current best internal CV score: 0.8263157894736842
#
# Generation 10 - Current best internal CV score: 0.8338121422960386
#
# Generation 11 - Current best internal CV score: 0.8338121422960386
#
# Generation 12 - Current best internal CV score: 0.8382897542363372
#
# Generation 13 - Current best internal CV score: 0.8382897542363372
#
# Generation 14 - Current best internal CV score: 0.8382897542363372
#
# Generation 15 - Current best internal CV score: 0.8397710694647065
#
# Generation 16 - Current best internal CV score: 0.8397710694647065
#
# Generation 17 - Current best internal CV score: 0.8397710694647065
#
# Generation 18 - Current best internal CV score: 0.8397935136348333
#
# Generation 19 - Current best internal CV score: 0.8397935136348333
#
# Generation 20 - Current best internal CV score: 0.8397935136348333
#
# Generation 21 - Current best internal CV score: 0.8397935136348333
#
# Generation 22 - Current best internal CV score: 0.8397935136348333
#
# Generation 23 - Current best internal CV score: 0.8397935136348333
#
# Generation 24 - Current best internal CV score: 0.8397935136348333
#
# Generation 25 - Current best internal CV score: 0.8412748288632027
#
# Generation 26 - Current best internal CV score: 0.8412860509482663
#
# Generation 27 - Current best internal CV score: 0.8412860509482663
#
# Generation 28 - Current best internal CV score: 0.8412860509482663
#
# Generation 29 - Current best internal CV score: 0.8412860509482663
#
# Generation 30 - Current best internal CV score: 0.8412860509482663
#
# Generation 31 - Current best internal CV score: 0.8412860509482663
#
# Generation 32 - Current best internal CV score: 0.8412972730333296
#
# Generation 33 - Current best internal CV score: 0.8412972730333296
#
# Generation 34 - Current best internal CV score: 0.8412972730333296
#
# Generation 35 - Current best internal CV score: 0.8412972730333296
#
# 10.01 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(DecisionTreeClassifier(input_matrix, criterion=entropy, max_depth=4, min_samples_leaf=1, min_samples_split=4), learning_rate=0.1, max_depth=10, min_child_weight=12, n_estimators=100, n_jobs=1, subsample=0.55, verbosity=0)
# TPOTClassifier(max_eval_time_mins=0.04, max_time_mins=10, population_size=40,
#                verbosity=2)

# %%
tpot.export('tpot_titanic_pipeline.py')
